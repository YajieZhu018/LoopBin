# %%
import dcss_ae as vae
import ae
import cluster_model
import numpy as np
import sys
sys.path.append('../fn')
import function
import importlib
from tensorflow.keras.models import load_model
import argparse
import sys
import pickle
from threading import local
import numpy as np
import init_data as init
import tensorflow as tf
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
# Out:
# 2024-03-27 14:09:03.283586: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# 2024-03-27 14:09:03.283632: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# reload if I changed sth
importlib.reload(cluster_model)
# Out:
# <module 'cluster_model' from '/usr/users/yzhu1/LoopHigh/src/model/cluster_model.py'>

# %%
# generate mix gaussian dataset of 100 samples with 3 features from with two means [0.1,0.3,0.5] and [1,3,5]
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
X, y = make_blobs(n_samples=100, centers=2, n_features=3, random_state=42)
# plot the data
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c=y)

# %%
# generate train and val data
train_dataset, train_label = make_blobs(n_samples=10000, centers=2, n_features=3, random_state=42)
val_dataset, val_label = make_blobs(n_samples=2000, centers=2, n_features=3, random_state=42)
# Scale the data to ensure centers are between 0 and 1
scaler = MinMaxScaler(feature_range=(0, 1))
train_dataset = scaler.fit_transform(train_dataset)
val_dataset = scaler.fit_transform(val_dataset)

# %%
train_dataset = tf.constant(train_dataset, dtype='float64')
val_dataset = tf.constant(val_dataset, dtype='float64')

# %%
print(np.mean(train_dataset[train_label==0],axis=0))
print(np.mean(train_dataset[train_label==1],axis=0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /local/jobs/19727668/ipykernel_190910/3478605248.py in <module>
# ----> 1 print(np.mean(train_dataset[train_label==0],axis=0))
#       2 print(np.mean(train_dataset[train_label==1],axis=0))
#
# TypeError: 'MapDataset' object is not subscriptable

# %%
# prepare training sets
batch_size = 256
# Prepare the training dataset.
train_data = tf.data.Dataset.from_tensor_slices(train_dataset)
train_data = train_data.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
val_data = tf.data.Dataset.from_tensor_slices(val_dataset)
val_data= val_data.batch(batch_size)

# %%
# load soft cluter model
# reload if I changed sth
importlib.reload(cluster_model)
import objectives
latent_dim = train_dataset.shape[1]
n_cluster = 2
n_epochs = 30
init_center = tf.constant([[-0.1,-0.2,-0.3],[0.1,0.1,0.1]],dtype='float64')
model = cluster_model.ClusterModel(latent_dim, n_cluster, n_epochs, init_center)
model.trainable_variables
model.train_process([train_data,val_data])
# Out:
# Training loss (for one batch) at step 0: 1.9835
# Training loss (for one batch) at step 10: 1.9812
# Training loss (for one batch) at step 20: 1.9805
# Training loss (for one batch) at step 30: 1.9769
# Epoch 1, Loss: 1.9795700120717576
# Validation Loss: 1.977608245160574
# Training loss (for one batch) at step 0: 1.9764
# Training loss (for one batch) at step 10: 1.9736
# Training loss (for one batch) at step 20: 1.9711
# Training loss (for one batch) at step 30: 1.9695
# Epoch 2, Loss: 1.9714450205881129
# Validation Loss: 1.9693376081933898
# Training loss (for one batch) at step 0: 1.9660
# Training loss (for one batch) at step 10: 1.9621
# Training loss (for one batch) at step 20: 1.9613
# Training loss (for one batch) at step 30: 1.9606
# Epoch 3, Loss: 1.9623980660515863
# Validation Loss: 1.9601915760685702
# Training loss (for one batch) at step 0: 1.9577
# Training loss (for one batch) at step 10: 1.9522
# Training loss (for one batch) at step 20: 1.9523
# ...

# %%
model.trainable_variables
# Out:
# [<tf.Variable 'rbf/centers:0' shape=(2, 3) dtype=float64, numpy=
#  array([[-0.45515615, -0.57818612, -0.66449882],
#         [ 0.61608242,  0.04300893,  0.09402695]])>,
#  <tf.Variable 'rbf/log_sigmas:0' shape=(2,) dtype=float64, numpy=array([-0.40219926, -0.00639307])>]

# %%
init_center
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[-2. ,  9. ,  4.1],
#        [ 2. ,  7. , -6. ]], dtype=float32)>

# %%
model.init_center
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[-2. ,  9. ,  4.1],
#        [ 2. ,  7. , -6. ]], dtype=float32)>

# %%
# prepare training sets
batch_size = 256
# Prepare the training dataset.
train_data = tf.data.Dataset.from_tensor_slices(train_dataset)
train_data = train_data.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
val_data = tf.data.Dataset.from_tensor_slices(val_dataset)
val_data= val_data.batch(batch_size)

# %%
init_center
# Out:
# <tf.Tensor: shape=(2, 3), dtype=float32, numpy=
# array([[-2. ,  9. ,  4.1],
#        [ 2. ,  7. , -6. ]], dtype=float32)>

# %%
inputs = train_dataset[0:2,:]
x = tf.expand_dims(inputs, 1)
x
# Out:
# <tf.Tensor: shape=(2, 1, 3), dtype=float32, numpy=
# array([[[-3.3139493, 10.572581 ,  5.4302697]],
#
#        [[-2.755533 ,  6.7128143,  3.819    ]]], dtype=float32)>

# %%
c = tf.expand_dims(init_center, 0)
c
# Out:
# <tf.Tensor: shape=(1, 2, 3), dtype=float32, numpy=
# array([[[-2. ,  9. ,  4.1],
#         [ 2. ,  7. , -6. ]]], dtype=float32)>

# %%
distances = tf.sqrt(tf.reduce_sum(tf.square(x - c), axis=-1))
distances
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[ 2.4431727, 13.101621 ],
#        [ 2.4250793, 10.913768 ]], dtype=float32)>

# %%
# Define basis functions
def gaussian(alpha):
    return tf.exp(-alpha**2)
gaussian(distances)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=float32, numpy=
# array([[0.00255656, 0.        ],
#        [0.00279196, 0.        ]], dtype=float32)>

# %%
il = '/usr/users/yzhu1/LoopHigh/Analysis/05_training/test_rep2_as_target/'
pretrained_weights = f'{il}/saved_model/my_TRUE_model_weights_clust.h5'
pretrained_latent_space = f'{il}/control_rep1/result/latent_space.npy'

# %%
with open(pretrained_latent_space, 'rb') as file_pointer:
            lat_space = np.load(file_pointer)

# %%
# get kmeans function
mcluster = KMeans(n_clusters=4, random_state=0).fit(lat_space)
#mcluster = function.set_kmeans(lat_space)
kmeans_center = mcluster.cluster_centers_

# %%
import matplotlib.pyplot as plt
il = '/usr/users/yzhu1/LoopHigh/Analysis/test_alexis/03_cluster/test_rep2_as_target/control/'
pretrained_latent_space = f'{il}/result/latent_space.npy'
with open(pretrained_latent_space, 'rb') as file_pointer:
            lat_space = np.load(file_pointer)
# get kmeans function
mcluster = KMeans(n_clusters=4, random_state=0).fit(lat_space)
#mcluster = function.set_kmeans(lat_space)
kmeans_center = mcluster.cluster_centers_
kmeans = mcluster
labels = kmeans.labels_

# Visualize the distribution of each feature within each cluster
n_features = lat_space.shape[1]
n_clusters = len(np.unique(labels))

plt.figure(figsize=(12, 20))

for i in range(n_features):
    plt.subplot(10, 5, i+1)
    for j in range(n_clusters):
        plt.hist(lat_space[labels==j, i], bins=20, alpha=0.5, label=f'Cluster {j}')
    plt.title(f'Feature {i+1} Distribution')
    plt.xlabel(f'Feature {i+1} value')
    plt.ylabel('Frequency')
    plt.legend()

plt.tight_layout()
pdf = f'{il}distribution_features.pdf'
plt.savefig(pdf)
plt.close()
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /local/jobs/19753075/ipykernel_521877/3094386816.py in <module>
#      29 pdf = f'{il}distribution_features.pdf'
#      30 plt.savefig(pdf)
# ---> 31 plt.closefig()
#      32 #plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'closefig'

# %%
il = '/usr/users/yzhu1/LoopHigh/Analysis/test_alexis/03_cluster/original_model/control_rep1/'
pretrained_latent_space = f'{il}/result/latent_space.npy'
with open(pretrained_latent_space, 'rb') as file_pointer:
            lat_space = np.load(file_pointer)
kmeans = mcluster
labels = kmeans.labels_

# Visualize the distribution of each feature within each cluster
n_features = lat_space.shape[1]
n_clusters = len(np.unique(labels))

plt.figure(figsize=(10, 28))

for i in range(n_features):
    plt.subplot(17, 3, i+1)
    for j in range(n_clusters):
        plt.hist(lat_space[labels==j, i], bins=20, alpha=0.5, label=f'Cluster {j}')
    plt.title(f'Feature {i+1} Distribution')
    plt.xlabel(f'Feature {i+1} value')
    plt.ylabel('Frequency')
    plt.legend()

plt.tight_layout()
plt.show()

# %%
# load training data
rep1 = '/usr/users/yzhu1/LoopHigh/Analysis/test_alexis/02_process/control_rep1/save/process_data.npy'
rep2 = '/usr/users/yzhu1/LoopHigh/Analysis/test_alexis/02_process/control_rep2/save/process_data.npy'
merged = '/usr/users/yzhu1/LoopHigh/Analysis/test_alexis/02_process/control/save/process_data.npy'
vae.set_random()
x_train, x_test, _, nbr_test = init.construct_input(rep1)
y_train, y_test, _, y_nbr_test = init.construct_input(rep2)
z_train, z_test, _, z_nbr_test = init.construct_input(merged)

# %%
# Train the model and save his weight
x_training, x_val, _, _ = init.construct_train(x_train)
y_training, y_val, _, _ = init.construct_train(y_train)
z_training, z_val, _, _ = init.construct_train(z_train)

# %%
batch_size = 256
# Prepare the training dataset.
x_training = x_training.astype('float64')
y_training = y_training.astype('float64')
z_training = z_training.astype('float64')
x_val = x_val.astype('float64')
y_val = y_val.astype('float64')
z_val = z_val.astype('float64')
train_dataset = tf.data.Dataset.from_tensor_slices((x_training, y_training,z_training))
train_dataset = train_dataset.shuffle(buffer_size=1024).batch(batch_size)

# Prepare the validation dataset.
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val,z_val))
val_dataset = val_dataset.batch(batch_size)
# Out:
# 2024-03-27 14:09:49.556205: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /.singularity.d/libs
# 2024-03-27 14:09:49.556253: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2024-03-27 14:09:49.556279: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (amp095): /proc/driver/nvidia/version does not exist
# 2024-03-27 14:09:49.576946: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def combine_features_labels_z(x, y, z):
    return (x, y), z
train_dataset = train_dataset.map(combine_features_labels_z)
val_dataset = val_dataset.map(combine_features_labels_z)

# %%
kmeans_center
# Out:
# array([[-0.0759116 , -0.03588723, -0.07874639, -0.25640684, -0.22622134,
#         -0.05227948,  0.21873425, -0.3253386 , -0.07581133,  0.08766513,
#          0.05815982, -0.25052333, -0.21716817,  0.05036917,  0.1107711 ,
#         -0.07208179,  0.3159358 ,  0.1289562 ,  0.06099996,  0.09988295,
#          0.00812167, -0.13712451, -0.05116665,  0.01847117, -0.24524802,
#          0.0805758 , -0.13171816],
#        [-0.2285892 , -0.06751911,  0.00304572,  0.50649345, -0.45971745,
#          0.28811124,  0.03954637, -0.29479146,  0.23049144,  0.3324288 ,
#          0.26177993,  0.22575694,  0.33404306,  0.22356832, -0.17320035,
#          0.23490077,  0.02982412,  0.24618053,  0.2714652 ,  0.33845067,
#          0.5576513 , -0.33079213,  0.31100294, -0.1028783 ,  0.16537277,
#         -0.19770598,  0.2920276 ],
#        [-0.11357006, -0.03610859, -0.23545907, -0.00971094, -0.21369138,
#          0.05482575,  0.11580833, -0.19443758, -0.04536343,  0.03659697,
# ...

# %%
# reload if I changed sth in vae.py
importlib.reload(vae)
latent_size = kmeans_center.shape[1]
new1 = vae.conv_VAE(latent_size, 3,kmeans_center)
n_clusters = 4
new1.set_train_variables(3, n_clusters, 5e-4, reconstruction_lambda=1, sil_lambda=0.001, entropy_lambda=0.01)
new1.train_process([train_dataset, val_dataset])
# Out:
# grads: [<tf.Tensor: shape=(3, 3, 5, 32), dtype=float64, numpy=
# array([[[[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]],
#
#         [[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan]]],
#
#
#        [[[nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
#          [nan, nan, nan, ..., nan, nan, nan],
# ...

# %%
new1([np.ones((20,16,16,5)),np.ones((20,16,16,5))])
new1.summary()
# Out:
# distance:[[nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]]
# gaussian distance:[[nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]
#  [nan nan nan nan]]
# Model: "conv_vae_9"
# _________________________________________________________________
# ...

# %%
pretrained_model = f'{il}/saved_model/my_VAE_model'
new1.load_pretrained_weights(pretrained_model)

# %%
new1.train_process([train_dataset, val_dataset])
# Out:
# distance:[[0.94085385 0.95548408 0.95331038 0.89556394]
#  [1.02093151 1.03304855 1.02699183 0.97148824]
#  [0.83908067 0.85489286 0.83130527 0.82334726]
#  [0.99353834 1.01272402 1.01920136 0.97032619]
#  [1.06461807 1.06888471 1.06185576 1.05915263]
#  [1.08092436 1.07177453 1.09023832 1.03491208]
#  [1.12731904 1.12474997 1.10123177 1.12631293]
#  [1.03042619 1.01807178 1.00784435 0.99737929]
#  [0.73481522 0.75551744 0.729188   0.7010356 ]
#  [0.79972246 0.85414372 0.81684247 0.78389069]
#  [0.79095572 0.90237314 0.78621091 0.81251792]
#  [0.74323132 0.79400407 0.72993456 0.73704944]
#  [1.27911419 1.31738813 1.28633278 1.28500336]
#  [0.8519163  0.83388444 0.83336897 0.78152075]
#  [0.86070205 0.86425272 0.87048862 0.81267316]
#  [1.28666955 1.30556275 1.25857238 1.30846902]
#  [1.18383636 1.19944988 1.16326812 1.19310288]
#  [1.16918881 1.16801269 1.12759334 1.17598517]
#  [1.5139503  1.4762337  1.47808285 1.48862103]
#  [0.9180233  0.98137507 0.90349797 0.94669144]
# ...

# %%
13429//256
# Out:
# 52
